# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
moffitt = pd.read_csv("Moffitt_radiation_project.csv")
dwinelle = pd.read_csv("Dwinelle_Hall_Radiation_project.csv")
etcheverry = pd.read_csv("Etcheverry_Radiation_Project.csv")
hearst = pd.read_csv("Hearst_Radiation_Project.csv")
waywest = pd.read_csv("Waywest_Radiation_project.csv")
evans = pd.read_csv("Evans_Hall_Radiation_project.csv")

# %%
moffitt_counts = moffitt['counts']
dwinelle_counts = dwinelle['counts']
etcheverry_counts = etcheverry['counts']
hearst_counts = hearst['counts']
waywest_counts = waywest['counts']
evans_counts= evans['counts']

# %%
moffitt['Time'] = moffitt['Time']-moffitt['Time'].iloc[0]
moffitt = moffitt.iloc[1:, :]
moffitt_counts = moffitt['counts']

# %%
plt.plot(moffitt['Time'], moffitt_counts)
plt.xlabel("Seconds")
plt.ylabel("Counts")
plt.title("Counts over Time at Moffitt")
# Out:
# Text(0.5, 1.0, 'Counts over Time at Moffitt')

# %%
dwinelle['Time'] = dwinelle['Time']-dwinelle['Time'].iloc[0]
dwinelle = dwinelle.iloc[1:, :]
dwinelle_counts = dwinelle['counts']

# %%
plt.plot(dwinelle['Time'], dwinelle_counts)
plt.xlabel("Seconds")
plt.ylabel("Counts")
plt.title("Counts over Time at Dwinelle")
# Out:
# Text(0.5, 1.0, 'Counts over Time at Dwinelle')

# %%
etcheverry['Time'] = etcheverry['Time']-etcheverry['Time'].iloc[0]
etcheverry = etcheverry.iloc[1:, :]
etcheverry_counts = etcheverry['counts']

plt.plot(etcheverry['Time'], etcheverry_counts)
plt.xlabel("Seconds")
plt.ylabel("Counts")
plt.title("Counts over Time at Etcheverry")
# Out:
# Text(0.5, 1.0, 'Counts over Time at Etcheverry')

# %%
hearst['Time'] = hearst['Time']-hearst['Time'].iloc[0]
hearst = hearst.iloc[1:, :]
hearst_counts = hearst['counts']

plt.plot(hearst['Time'], hearst_counts)
plt.xlabel("Seconds")
plt.ylabel("Counts")
plt.title("Counts over Time at Hearst")
# Out:
# Text(0.5, 1.0, 'Counts over Time at Hearst')

# %%
waywest['Time'] = waywest['Time']-waywest['Time'].iloc[0]
waywest = waywest.iloc[1:, :]
waywest_counts = waywest['counts']

plt.plot(waywest['Time'], waywest_counts)
plt.xlabel("Seconds")
plt.ylabel("Counts")
plt.title("Counts over Time at WayWest")
# Out:
# Text(0.5, 1.0, 'Counts over Time at WayWest')

# %%
evans['Time'] = evans['Time']-evans['Time'].iloc[0]
evans = evans.iloc[1:, :]
evans_counts = evans['counts']

plt.plot(evans['Time'], evans_counts)
plt.xlabel("Seconds")
plt.ylabel("Counts")
plt.title("Counts over Time at Evans Hall")
# Out:
# Text(0.5, 1.0, 'Counts over Time at Evans Hall')

# %%
plt.hist(moffitt_counts)
plt.xlabel("Counts")
plt.ylabel("Number of Counts")
plt.title("Count Distribution at Moffitt")
plt.plot(np.mean(moffitt_counts), 400, 'ro', label = 'Moffitt Mean')
plt.plot(np.median(moffitt_counts), 300, 'yo', label = 'Moffitt Median')
plt.legend()

# %%
print("The mean counts for Moffitt over a span of an hour is", np.mean(moffitt_counts), "counts.")
print("The median counts for Moffitt over the span of an hour is", np.median(moffitt_counts), "counts.")
# Out:
# The mean counts for Moffitt over a span of an hour is 36.60289389067524 counts.
# The median counts for Moffitt over the span of an hour is 36.5 counts.

# %%
plt.hist(dwinelle_counts)
plt.xlabel("Counts")
plt.ylabel("Number of Counts")
plt.title("Count Distribution at Dwinelle")
plt.plot(np.mean(dwinelle_counts), 400, 'ro', label = 'Dwinelle Mean')
plt.plot(np.median(dwinelle_counts), 300, 'yo', label = 'Dwinelle Median')
plt.legend()

# %%
print("The mean counts for Dwinelle over a span of an hour is", np.mean(dwinelle_counts), "counts.")
print("The median counts for Dwinelle over the span of an hour is", np.median(dwinelle_counts), "counts.")
# Out:
# The mean counts for Dwinelle over a span of an hour is 31.4 counts.
# The median counts for Dwinelle over the span of an hour is 31.5 counts.

# %%
plt.hist(etcheverry_counts)
plt.xlabel("Counts")
plt.ylabel("Number of Counts")
plt.title("Count Distribution at Etcheverry")
plt.plot(np.mean(etcheverry_counts), 400, 'ro', label = 'Etcheverry Mean')
plt.plot(np.median(etcheverry_counts), 300, 'yo', label = 'Etcheverry Median')
plt.legend()

# %%
print("The mean counts for Etcheverry over a span of an hour is", np.mean(etcheverry_counts), "counts.")
print("The median counts for Etcheverry over the span of an hour is", np.median(etcheverry_counts), "counts.")
# Out:
# The mean counts for Etcheverry over a span of an hour is 56.26985458612975 counts.
# The median counts for Etcheverry over the span of an hour is 56.0 counts.

# %%
plt.hist(hearst_counts)
plt.xlabel("Counts")
plt.ylabel("Number of Counts")
plt.title("Count Distribution at Hearst")
plt.plot(np.mean(hearst_counts), 400, 'ro', label = 'Hearst Mean')
plt.plot(np.median(hearst_counts), 300, 'yo', label = 'Hearst Median')
plt.legend()

# %%
print("The mean counts for Hearst over a span of an hour is", np.mean(hearst_counts), "counts.")
print("The median counts for Hearst over the span of an hour is", np.median(hearst_counts), "counts.")
# Out:
# The mean counts for Hearst over a span of an hour is 66.1817192600653 counts.
# The median counts for Hearst over the span of an hour is 66.0 counts.

# %%
plt.hist(waywest_counts)
plt.xlabel("Counts")
plt.ylabel("Number of Counts")
plt.title("Count Distribution at Waywest")
plt.plot(np.mean(waywest_counts), 400, 'ro', label = 'Waywest Mean')
plt.plot(np.median(waywest_counts), 300, 'yo', label = 'Waywest Median')
plt.legend()

# %%
print("The mean counts for Waywest over a span of an hour is", np.mean(waywest_counts), "counts.")
print("The median counts for Waywest over the span of an hour is", np.median(waywest_counts), "counts.")
# Out:
# The mean counts for Waywest over a span of an hour is 26.46967380224261 counts.
# The median counts for Waywest over the span of an hour is 26.5 counts.

# %%
plt.hist(evans_counts)
plt.xlabel("Counts")
plt.ylabel("Number of Counts")
plt.title("Count Distribution at Evans")
plt.plot(np.mean(evans_counts), 400, 'ro', label = 'Evans Mean')
plt.plot(np.median(evans_counts), 300, 'yo', label = 'Evans Median')
plt.legend()

# %%
print("The mean counts for Evans over a span of an hour is", np.mean(evans_counts), "counts.")
print("The median counts for Evans over the span of an hour is", np.median(evans_counts), "counts.")
# Out:
# The mean counts for Evans over a span of an hour is 41.828947368421055 counts.
# The median counts for Evans over the span of an hour is 41.5 counts.

# %%
plt.hist(moffitt_counts, label = "Moffitt", alpha = 0.5)
plt.hist(dwinelle_counts, label = "Dwinelle", alpha = 0.5)
plt.hist(evans_counts, label = "Evans", alpha = 0.5)
plt.hist(waywest_counts, label = "Waywest", alpha = 0.5)
plt.hist(hearst_counts, label = "Hearst", alpha = 0.5)
plt.xlabel("Counts")
plt.ylabel("Number")
plt.title("Distribution of Counts Across Different Berkeley Locations")
plt.legend()

# %%
print("Moffitt mean counts is", np.mean(moffitt_counts), "counts.")
print("Dwinelle mean counts is", np.mean(dwinelle_counts), "counts.")
print("Evans mean counts is", np.mean(evans_counts), "counts.")
print("Waywest mean counts is", np.mean(waywest_counts), "counts.")
print("Hearst mean counts is", np.mean(hearst_counts), "counts.")
# Out:
# Moffitt mean counts is 36.60289389067524 counts.
# Dwinelle mean counts is 31.4 counts.
# Evans mean counts is 41.828947368421055 counts.
# Waywest mean counts is 26.46967380224261 counts.
# Hearst mean counts is 66.1817192600653 counts.
