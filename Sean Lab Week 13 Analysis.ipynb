# %%
import numpy as np 
import matplotlib.pyplot as plt 
import pandas as pd

# %%
df = pd.read_csv('Loc1_session1_group1_2024-04-12_16-14-40.csv')

# %%
#Temperature:
df_Temperature = df['Temperature']

#b.
plt.hist(df_Temperature)
plt.xlabel('Temperature (C)')
plt.ylabel('Frequency')
plt.title('Occurances in Temperature throughout experiment')

mean_Temperature = np.mean(df_Temperature)
std_Temperature = np.std(df_Temperature)

print(f'Temperature Mean = {mean_Temperature}')
print(f'Temperature std = {std_Temperature}')

#c. 
sum_xi_x_2_Temperature = []
for i in range(len(df_Temperature)):
    sum_xi_x_2_Temperature_i = (df_Temperature[i] - mean_Temperature)**2
    sum_xi_x_2_Temperature.append(sum_xi_x_2_Temperature_i)
sum_xi_x_2_Temperature = np.sum(sum_xi_x_2_Temperature)

variance_Temperature = np.sqrt(sum_xi_x_2_Temperature/(len(df_Temperature)-1))
print(f'Temperature variance = {variance_Temperature}')

#d.
N = np.sum(df_Temperature)
N_samples = len(df_Temperature)
uncertainty = np.sqrt(N)/np.sqrt(2*np.sqrt(N_samples))
print(f'Uncertainty = {uncertainty}')
# Out:
# Temperature Mean = 23.408381520669295
# Temperature std = 2.5366641369576857
# Temperature variance = 2.5467103708749335
# Uncertainty = 11.484752117682481

# %%
#a. 
plt.plot(df_Temperature)
plt.xlabel('Time (5 seconds)')
plt.ylabel('Temperature (C)')
plt.title('Temperature vs. Time')
# Out:
# Text(0.5, 1.0, 'Temperature vs. Time')

# %%
#PM25:
df_PM25 = df['PM25']

#b.
plt.hist(df_PM25)
plt.xlabel('PM25 (ppm)')
plt.ylabel('Frequency')
plt.title('Occurances in ppm throughout experiment')

mean_PM25 = np.mean(df_PM25)
std_PM25 = np.std(df_PM25)

print(f'PM25 Mean = {mean_PM25}')
print(f'PM25 std = {std_PM25}')

#c. 
sum_xi_x_2_PM25 = []
for i in range(len(df_PM25)):
    sum_xi_x_2_PM25_i = (df_PM25[i] - mean_PM25)**2
    sum_xi_x_2_PM25.append(sum_xi_x_2_PM25_i)
sum_xi_x_2_PM25 = np.sum(sum_xi_x_2_PM25)

variance_PM25 = np.sqrt(sum_xi_x_2_PM25/(len(df_PM25)-1))
print(f'PM25 variance = {variance_PM25}')

#d.
N = np.sum(df_PM25)
N_samples = len(df_PM25)
uncertainty = np.sqrt(N)/np.sqrt(2*np.sqrt(N_samples))
print(f'Uncertainty = {uncertainty}')
# Out:
# PM25 Mean = 1.9842519685039366
# PM25 std = 1.446495912438348
# PM25 variance = 1.4522246315403287
# Uncertainty = 3.3437541803552233

# %%
#b. 
plt.plot(df_PM25)
plt.xlabel('Time (5 seconds)')
plt.ylabel('Amount of 2.5 PPM')
plt.title('PPM vs. Time')
# Out:
# Text(0.5, 1.0, 'PPM vs. Time')

# %%
#counts:
df_counts = df['counts']

#b.
plt.hist(df_counts)
plt.xlabel('counts')
plt.ylabel('Frequency')
plt.title('Occurances in counts throughout experiment')

mean_counts = np.mean(df_counts)
std_counts = np.std(df_counts)

print(f'counts Mean = {mean_counts}')
print(f'counts std = {std_counts}')

#c. 
sum_xi_x_2_counts = []
for i in range(len(df_counts)):
    sum_xi_x_2_counts_i = (df_counts[i] - mean_counts)**2
    sum_xi_x_2_counts.append(sum_xi_x_2_counts_i)
sum_xi_x_2_counts = np.sum(sum_xi_x_2_counts)

variance_counts = np.sqrt(sum_xi_x_2_counts/(len(df_counts)-1))
print(f'counts variance = {variance_counts}')

#d.
N = np.sum(df_counts)
N_samples = len(df_counts)
uncertainty = np.sqrt(N)/np.sqrt(2*np.sqrt(N_samples))
print(f'Uncertainty = {uncertainty}')
# Out:
# counts Mean = 30.28976377952756
# counts std = 4.427737102596732
# counts variance = 4.445272763707198
# Uncertainty = 13.064231742475151

# %%
#a. 
plt.plot(df_counts)
plt.xlabel('Time (5 seconds)')
plt.ylabel('Counts')
plt.title('Counts vs. Time')
# Out:
# Text(0.5, 1.0, 'Counts vs. Time')
